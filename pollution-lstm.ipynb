# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('/kaggle/input/naveen/PRSA_data_2010.1.1-2014.12.31.csv')
df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.isnull().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# pm2.5    2067
# DEWP        0
# TEMP        0
# PRES        0
# cbwd        0
# Iws         0
# Is          0
# Ir          0
# dtype: int64

# %%
df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean   21912.500000   2012.000000      6.523549     15.727820     11.500000
# std    12651.043435      1.413842      3.448572      8.799425      6.922266
# min        1.000000   2010.000000      1.000000      1.000000      0.000000
# 25%    10956.750000   2011.000000      4.000000      8.000000      5.750000
# 50%    21912.500000   2012.000000      7.000000     16.000000     11.500000
# 75%    32868.250000   2013.000000     10.000000     23.000000     17.250000
# max    43824.000000   2014.000000     12.000000     31.000000     23.000000
#
#               pm2.5          DEWP          TEMP          PRES           Iws  \
# count  41757.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean      98.613215      1.817246     12.448521   1016.447654     23.889140
# std       92.050387     14.433440     12.198613     10.268698     50.010635
# min        0.000000    -40.000000    -19.000000    991.000000      0.450000
# 25%       29.000000    -10.000000      2.000000   1008.000000      1.790000
# 50%       72.000000      2.000000     14.000000   1016.000000      5.370000
# 75%      137.000000     15.000000     23.000000   1025.000000     21.910000
# max      994.000000     28.000000     42.000000   1046.000000    585.600000
#
#                  Is            Ir
# count  43824.000000  43824.000000
# mean       0.052734      0.194916
# std        0.760375      1.415867
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       27.000000     36.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      43824 non-null  int64
#  1   year    43824 non-null  int64
#  2   month   43824 non-null  int64
#  3   day     43824 non-null  int64
#  4   hour    43824 non-null  int64
#  5   pm2.5   41757 non-null  float64
#  6   DEWP    43824 non-null  int64
#  7   TEMP    43824 non-null  float64
#  8   PRES    43824 non-null  float64
#  9   cbwd    43824 non-null  object
#  10  Iws     43824 non-null  float64
#  11  Is      43824 non-null  int64
#  12  Ir      43824 non-null  int64
# dtypes: float64(4), int64(8), object(1)
# memory usage: 4.3+ MB

# %%
sns.boxplot(x='pm2.5',data = df)
# Out:
# <Axes: xlabel='pm2.5'>

# %%
df.rename(columns = {'pm2.5': 'Pollution',
                     'DEWP':'Dew',
                     'TEMP':'Temperature',
                     'PRES':'Pressure',
                     'cbwd':'Wind Dir',
                     'Iws':'Wind Speed',
                     'Is':'hours of snow',
                     'Ir':'hours of rain'},inplace = True)

# %%
df.head()
# Out:
#    No  year  month  day  hour  Pollution  Dew  Temperature  Pressure Wind Dir  \
# 0   1  2010      1    1     0        NaN  -21        -11.0    1021.0       NW
# 1   2  2010      1    1     1        NaN  -21        -12.0    1020.0       NW
# 2   3  2010      1    1     2        NaN  -21        -11.0    1019.0       NW
# 3   4  2010      1    1     3        NaN  -21        -14.0    1019.0       NW
# 4   5  2010      1    1     4        NaN  -20        -12.0    1018.0       NW
#
#    Wind Speed  hours of snow  hours of rain
# 0        1.79              0              0
# 1        4.92              0              0
# 2        6.71              0              0
# 3        9.84              0              0
# 4       12.97              0              0

# %%
df.fillna(0,inplace = True)

# %%
df.isnull().sum()
# Out:
# No               0
# year             0
# month            0
# day              0
# hour             0
# Pollution        0
# Dew              0
# Temperature      0
# Pressure         0
# Wind Dir         0
# Wind Speed       0
# hours of snow    0
# hours of rain    0
# dtype: int64

# %%
df.drop(['No'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    year  month  day  hour  Pollution  Dew  Temperature  Pressure Wind Dir  \
# 0  2010      1    1     0        0.0  -21        -11.0    1021.0       NW
# 1  2010      1    1     1        0.0  -21        -12.0    1020.0       NW
# 2  2010      1    1     2        0.0  -21        -11.0    1019.0       NW
# 3  2010      1    1     3        0.0  -21        -14.0    1019.0       NW
# 4  2010      1    1     4        0.0  -20        -12.0    1018.0       NW
#
#    Wind Speed  hours of snow  hours of rain
# 0        1.79              0              0
# 1        4.92              0              0
# 2        6.71              0              0
# 3        9.84              0              0
# 4       12.97              0              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           43824 non-null  int64
#  1   month          43824 non-null  int64
#  2   day            43824 non-null  int64
#  3   hour           43824 non-null  int64
#  4   Pollution      43824 non-null  float64
#  5   Dew            43824 non-null  int64
#  6   Temperature    43824 non-null  float64
#  7   Pressure       43824 non-null  float64
#  8   Wind Dir       43824 non-null  object
#  9   Wind Speed     43824 non-null  float64
#  10  hours of snow  43824 non-null  int64
#  11  hours of rain  43824 non-null  int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 4.0+ MB

# %%
df['Date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
df.head()
# Out:
#    year  month  day  hour  Pollution  Dew  Temperature  Pressure Wind Dir  \
# 0  2010      1    1     0        0.0  -21        -11.0    1021.0       NW
# 1  2010      1    1     1        0.0  -21        -12.0    1020.0       NW
# 2  2010      1    1     2        0.0  -21        -11.0    1019.0       NW
# 3  2010      1    1     3        0.0  -21        -14.0    1019.0       NW
# 4  2010      1    1     4        0.0  -20        -12.0    1018.0       NW
#
#    Wind Speed  hours of snow  hours of rain                Date
# 0        1.79              0              0 2010-01-01 00:00:00
# 1        4.92              0              0 2010-01-01 01:00:00
# 2        6.71              0              0 2010-01-01 02:00:00
# 3        9.84              0              0 2010-01-01 03:00:00
# 4       12.97              0              0 2010-01-01 04:00:00

# %%
x = df.iloc[:,:4]

# %%
x
# Out:
#        year  month  day  hour
# 0      2010      1    1     0
# 1      2010      1    1     1
# 2      2010      1    1     2
# 3      2010      1    1     3
# 4      2010      1    1     4
# ...     ...    ...  ...   ...
# 43819  2014     12   31    19
# 43820  2014     12   31    20
# 43821  2014     12   31    21
# 43822  2014     12   31    22
# 43823  2014     12   31    23
#
# [43824 rows x 4 columns]

# %%
df.drop(['year','month','day','hour'],axis =1, inplace = True)

# %%
df.head()
# Out:
#    Pollution  Dew  Temperature  Pressure Wind Dir  Wind Speed  hours of snow  \
# 0        0.0  -21        -11.0    1021.0       NW        1.79              0
# 1        0.0  -21        -12.0    1020.0       NW        4.92              0
# 2        0.0  -21        -11.0    1019.0       NW        6.71              0
# 3        0.0  -21        -14.0    1019.0       NW        9.84              0
# 4        0.0  -20        -12.0    1018.0       NW       12.97              0
#
#    hours of rain                Date
# 0              0 2010-01-01 00:00:00
# 1              0 2010-01-01 01:00:00
# 2              0 2010-01-01 02:00:00
# 3              0 2010-01-01 03:00:00
# 4              0 2010-01-01 04:00:00

# %%
# df.set_index('Date',inplace=True)

# %%
columns = df.columns.tolist()

# Move the last column to the first position
columns = [columns[-1]] + columns[:-1]

# Reorder the DataFrame columns
df = df[columns]
df.head()
# Out:
#                  Date  Pollution  Dew  Temperature  Pressure Wind Dir  \
# 0 2010-01-01 00:00:00        0.0  -21        -11.0    1021.0       NW
# 1 2010-01-01 01:00:00        0.0  -21        -12.0    1020.0       NW
# 2 2010-01-01 02:00:00        0.0  -21        -11.0    1019.0       NW
# 3 2010-01-01 03:00:00        0.0  -21        -14.0    1019.0       NW
# 4 2010-01-01 04:00:00        0.0  -20        -12.0    1018.0       NW
#
#    Wind Speed  hours of snow  hours of rain
# 0        1.79              0              0
# 1        4.92              0              0
# 2        6.71              0              0
# 3        9.84              0              0
# 4       12.97              0              0

# %%
df.values
# Out:
# array([[Timestamp('2010-01-01 00:00:00'), 0.0, -21, ..., 1.79, 0, 0],
#        [Timestamp('2010-01-01 01:00:00'), 0.0, -21, ..., 4.92, 0, 0],
#        [Timestamp('2010-01-01 02:00:00'), 0.0, -21, ..., 6.71, 0, 0],
#        ...,
#        [Timestamp('2014-12-31 21:00:00'), 10.0, -22, ..., 242.7, 0, 0],
#        [Timestamp('2014-12-31 22:00:00'), 8.0, -22, ..., 246.72, 0, 0],
#        [Timestamp('2014-12-31 23:00:00'), 12.0, -21, ..., 249.85, 0, 0]],
#       dtype=object)

# %%
plt.plot(df[35:8765]['Pressure'])
plt.xticks(rotation= 90)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000.]),
#  [Text(-2000.0, 0, '−2000'),
#   Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000')])

# %%
# columns = df.columns.tolist()

# columns = [columns[-1]] + columns[:-1]

# df = df[columns]
# df.head()

# %%
df.isnull().sum()
# Out:
# Date             0
# Pollution        0
# Dew              0
# Temperature      0
# Pressure         0
# Wind Dir         0
# Wind Speed       0
# hours of snow    0
# hours of rain    0
# dtype: int64

# %%
# values = df.values

# # Specify columns to plot
# groups = [0, 1, 2, 3, 5, 6, 7]
# num_groups = len(groups)

# # Create subplots
# fig, axes = plt.subplots(num_groups, 1, figsize=(10, 10))

# # Plot each column in a separate subplot
# for i, group in enumerate(groups):
#     ax = axes[i] if num_groups > 1 else axes  # Handle single subplot case
#     ax.plot(values[:, group])
#     ax.set_title(df.columns[group], y=0.5, loc='right')  # Set subplot title

# # Adjust layout and display the plot
# fig.tight_layout()
# plt.show()

# %%
values = df.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
# prepare data for lstm
from pandas import read_csv,DataFrame,concat
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %%
cat = df.select_dtypes(include='object')
cat
# Out:
#       Wind Dir
# 0           NW
# 1           NW
# 2           NW
# 3           NW
# 4           NW
# ...        ...
# 43819       NW
# 43820       NW
# 43821       NW
# 43822       NW
# 43823       NW
#
# [43824 rows x 1 columns]

# %%
le = LabelEncoder()

# %%
cat = le.fit_transform(cat)

# %%
cat.shape
# Out:
# (43824,)

# %%
cat.dtype
# Out:
# dtype('int64')

# %%
df.head(2)
# Out:
#                  Date  Pollution  Dew  Temperature  Pressure Wind Dir  \
# 0 2010-01-01 00:00:00        0.0  -21        -11.0    1021.0       NW
# 1 2010-01-01 01:00:00        0.0  -21        -12.0    1020.0       NW
#
#    Wind Speed  hours of snow  hours of rain
# 0        1.79              0              0
# 1        4.92              0              0

# %%
df['Wind Dir'] = cat

# %%
df = df[24:]

# %%
df
# Out:
#                      Date  Pollution  Dew  Temperature  Pressure  Wind Dir  \
# 24    2010-01-02 00:00:00      129.0  -16         -4.0    1020.0         2
# 25    2010-01-02 01:00:00      148.0  -15         -4.0    1020.0         2
# 26    2010-01-02 02:00:00      159.0  -11         -5.0    1021.0         2
# 27    2010-01-02 03:00:00      181.0   -7         -5.0    1022.0         2
# 28    2010-01-02 04:00:00      138.0   -7         -5.0    1022.0         2
# ...                   ...        ...  ...          ...       ...       ...
# 43819 2014-12-31 19:00:00        8.0  -23         -2.0    1034.0         1
# 43820 2014-12-31 20:00:00       10.0  -22         -3.0    1034.0         1
# 43821 2014-12-31 21:00:00       10.0  -22         -3.0    1034.0         1
# 43822 2014-12-31 22:00:00        8.0  -22         -4.0    1034.0         1
# 43823 2014-12-31 23:00:00       12.0  -21         -3.0    1034.0         1
#
#        Wind Speed  hours of snow  hours of rain
# 24           1.79              0              0
# 25           2.68              0              0
# 26           3.57              0              0
# 27           5.36              1              0
# 28           6.25              2              0
# ...           ...            ...            ...
# 43819      231.97              0              0
# 43820      237.78              0              0
# 43821      242.70              0              0
# 43822      246.72              0              0
# 43823      249.85              0              0
#
# [43800 rows x 9 columns]

# %%
df['Wind Dir'].dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#                   Date  Pollution  Dew  Temperature  Pressure  Wind Dir  \
# 24 2010-01-02 00:00:00      129.0  -16         -4.0    1020.0         2
# 25 2010-01-02 01:00:00      148.0  -15         -4.0    1020.0         2
# 26 2010-01-02 02:00:00      159.0  -11         -5.0    1021.0         2
# 27 2010-01-02 03:00:00      181.0   -7         -5.0    1022.0         2
# 28 2010-01-02 04:00:00      138.0   -7         -5.0    1022.0         2
#
#     Wind Speed  hours of snow  hours of rain
# 24        1.79              0              0
# 25        2.68              0              0
# 26        3.57              0              0
# 27        5.36              1              0
# 28        6.25              2              0

# %%
df.drop(['Date'],axis = 1, inplace = True)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # Input sequence (t-n, ..., t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Forecast sequence (t, t+1, ..., t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Concatenate input and forecast sequences
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    
    return agg

# %%
# ensure all data is float
df = df.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df)

# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658

# %%
reframed.shape
# Out:
# (43799, 9)

# %%
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8760, 1, 8) (8760,) (35039, 1, 8) (35039,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
# Out:
# 2024-04-16 13:44:28.686089: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 13:44:28.686158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 13:44:28.687844: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 122/122 - 3s - 25ms/step - loss: 0.0625 - val_loss: 0.0515
# Epoch 2/50
# 122/122 - 1s - 10ms/step - loss: 0.0420 - val_loss: 0.0558
# Epoch 3/50
# 122/122 - 1s - 8ms/step - loss: 0.0259 - val_loss: 0.0428
# Epoch 4/50
# 122/122 - 1s - 8ms/step - loss: 0.0176 - val_loss: 0.0309
# Epoch 5/50
# 122/122 - 1s - 8ms/step - loss: 0.0152 - val_loss: 0.0172
# Epoch 6/50
# 122/122 - 1s - 8ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 7/50
# 122/122 - 1s - 8ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 8/50
# 122/122 - 2s - 13ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 9/50
# 122/122 - 1s - 8ms/step - loss: 0.0149 - val_loss: 0.0143
# Epoch 10/50
# 122/122 - 2s - 13ms/step - loss: 0.0146 - val_loss: 0.0143
# Epoch 11/50
# 122/122 - 1s - 8ms/step - loss: 0.0147 - val_loss: 0.0141
# Epoch 12/50
# 122/122 - 1s - 10ms/step - loss: 0.0146 - val_loss: 0.0144
# Epoch 13/50
# 122/122 - 1s - 11ms/step - loss: 0.0149 - val_loss: 0.0141
# Epoch 14/50
# 122/122 - 2s - 13ms/step - loss: 0.0146 - val_loss: 0.0138
# Epoch 15/50
# 122/122 - 3s - 21ms/step - loss: 0.0147 - val_loss: 0.0141
# Epoch 16/50
# 122/122 - 1s - 8ms/step - loss: 0.0147 - val_loss: 0.0138
# Epoch 17/50
# 122/122 - 1s - 10ms/step - loss: 0.0146 - val_loss: 0.0138
# Epoch 18/50
# 122/122 - 2s - 15ms/step - loss: 0.0145 - val_loss: 0.0142
# Epoch 19/50
# 122/122 - 2s - 13ms/step - loss: 0.0147 - val_loss: 0.0138
# Epoch 20/50
# 122/122 - 2s - 16ms/step - loss: 0.0145 - val_loss: 0.0140
# Epoch 21/50
# 122/122 - 2s - 15ms/step - loss: 0.0146 - val_loss: 0.0137
# Epoch 22/50
# 122/122 - 2s - 13ms/step - loss: 0.0146 - val_loss: 0.0138
# Epoch 23/50
# 122/122 - 2s - 13ms/step - loss: 0.0147 - val_loss: 0.0138
# Epoch 24/50
# 122/122 - 2s - 13ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 25/50
# 122/122 - 2s - 13ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 26/50
# 122/122 - 1s - 8ms/step - loss: 0.0145 - val_loss: 0.0138
# Epoch 27/50
# 122/122 - 2s - 13ms/step - loss: 0.0145 - val_loss: 0.0138
# Epoch 28/50
# 122/122 - 1s - 8ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 29/50
# 122/122 - 2s - 13ms/step - loss: 0.0145 - val_loss: 0.0136
# Epoch 30/50
# 122/122 - 3s - 21ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 31/50
# 122/122 - 1s - 8ms/step - loss: 0.0145 - val_loss: 0.0136
# Epoch 32/50
# 122/122 - 1s - 8ms/step - loss: 0.0145 - val_loss: 0.0136
# Epoch 33/50
# 122/122 - 2s - 15ms/step - loss: 0.0145 - val_loss: 0.0136
# Epoch 34/50
# 122/122 - 1s - 8ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 35/50
# 122/122 - 1s - 7ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 36/50
# 122/122 - 1s - 7ms/step - loss: 0.0144 - val_loss: 0.0138
# Epoch 37/50
# 122/122 - 1s - 8ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 38/50
# 122/122 - 1s - 9ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 39/50
# 122/122 - 1s - 10ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 40/50
# 122/122 - 1s - 8ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 41/50
# 122/122 - 1s - 8ms/step - loss: 0.0144 - val_loss: 0.0137
# Epoch 42/50
# 122/122 - 1s - 8ms/step - loss: 0.0144 - val_loss: 0.0138
# Epoch 43/50
# 122/122 - 2s - 15ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 44/50
# 122/122 - 1s - 8ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 45/50
# 122/122 - 1s - 8ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 46/50
# 122/122 - 1s - 8ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 47/50
# 122/122 - 2s - 13ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 48/50
# 122/122 - 2s - 13ms/step - loss: 0.0143 - val_loss: 0.0136
# Epoch 49/50
# 122/122 - 1s - 8ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 50/50
# 122/122 - 2s - 13ms/step - loss: 0.0143 - val_loss: 0.0135

# %%
# Assuming 'model' is already defined and trained
# 'test_X' is the input features for the test dataset
from sklearn.metrics import mean_squared_error
# Make predictions
yhat = model.predict(test_X)

# Reshape test_X if needed
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]

# Invert scaling for actual
test_y_reshaped = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_reshaped, test_X_reshaped[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Test RMSE: 26.535

# %% [markdown]
# # Evaluate Model

# %% [markdown]
# # Train on Multiple Lag Timestamps

# %%
# # specify the number of lag hours
# n_hours = 3
# n_features = 8
# # frame as supervised learning
# reframed = series_to_supervised(scaled, n_hours, 1)

# %%
train_X.size
# Out:
# 70080

# %%
print("Current shape of train_X:", train_X.shape)
print("Total number of elements in train_X:", train_X.size)
# Out:
# Current shape of train_X: (8760, 1, 8)
# Total number of elements in train_X: 70080

# %%
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import numpy as np

# Specify the number of lag hours and features
n_hours = 3
n_features = 8

# Frame the dataset as supervised learning
# (Assuming 'series_to_supervised()' function is defined elsewhere)
reframed = series_to_supervised(scaled, n_hours, 1)
print(reframed.shape)

# Split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# Split into input (X) and output (y) variables
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]

# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

# Print shapes for verification
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (43797, 32)
# (8760, 3, 8) (8760,) (35037, 3, 8) (35037,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 122/122 - 3s - 27ms/step - loss: 0.0425 - val_loss: 0.0522
# Epoch 2/50
# 122/122 - 3s - 22ms/step - loss: 0.0231 - val_loss: 0.0384
# Epoch 3/50
# 122/122 - 2s - 18ms/step - loss: 0.0213 - val_loss: 0.0273
# Epoch 4/50
# 122/122 - 1s - 11ms/step - loss: 0.0205 - val_loss: 0.0217
# Epoch 5/50
# 122/122 - 1s - 11ms/step - loss: 0.0203 - val_loss: 0.0214
# Epoch 6/50
# 122/122 - 1s - 11ms/step - loss: 0.0198 - val_loss: 0.0210
# Epoch 7/50
# 122/122 - 3s - 22ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 8/50
# 122/122 - 3s - 23ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 9/50
# 122/122 - 1s - 11ms/step - loss: 0.0183 - val_loss: 0.0181
# Epoch 10/50
# 122/122 - 2s - 14ms/step - loss: 0.0180 - val_loss: 0.0176
# Epoch 11/50
# 122/122 - 1s - 11ms/step - loss: 0.0176 - val_loss: 0.0164
# Epoch 12/50
# 122/122 - 1s - 11ms/step - loss: 0.0171 - val_loss: 0.0160
# Epoch 13/50
# 122/122 - 2s - 13ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 14/50
# 122/122 - 2s - 18ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 15/50
# 122/122 - 1s - 10ms/step - loss: 0.0160 - val_loss: 0.0154
# Epoch 16/50
# 122/122 - 3s - 25ms/step - loss: 0.0154 - val_loss: 0.0150
# Epoch 17/50
# 122/122 - 1s - 11ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 18/50
# 122/122 - 1s - 11ms/step - loss: 0.0150 - val_loss: 0.0166
# Epoch 19/50
# 122/122 - 2s - 14ms/step - loss: 0.0148 - val_loss: 0.0174
# Epoch 20/50
# 122/122 - 2s - 14ms/step - loss: 0.0147 - val_loss: 0.0175
# Epoch 21/50
# 122/122 - 1s - 10ms/step - loss: 0.0147 - val_loss: 0.0178
# Epoch 22/50
# 122/122 - 1s - 10ms/step - loss: 0.0145 - val_loss: 0.0166
# Epoch 23/50
# 122/122 - 1s - 10ms/step - loss: 0.0146 - val_loss: 0.0155
# Epoch 24/50
# 122/122 - 2s - 14ms/step - loss: 0.0145 - val_loss: 0.0154
# Epoch 25/50
# 122/122 - 2s - 18ms/step - loss: 0.0145 - val_loss: 0.0151
# Epoch 26/50
# 122/122 - 1s - 11ms/step - loss: 0.0146 - val_loss: 0.0148
# Epoch 27/50
# 122/122 - 2s - 14ms/step - loss: 0.0145 - val_loss: 0.0149
# Epoch 28/50
# 122/122 - 1s - 11ms/step - loss: 0.0144 - val_loss: 0.0144
# Epoch 29/50
# 122/122 - 3s - 21ms/step - loss: 0.0144 - val_loss: 0.0147
# Epoch 30/50
# 122/122 - 2s - 20ms/step - loss: 0.0145 - val_loss: 0.0144
# Epoch 31/50
# 122/122 - 2s - 14ms/step - loss: 0.0144 - val_loss: 0.0144
# Epoch 32/50
# 122/122 - 2s - 14ms/step - loss: 0.0144 - val_loss: 0.0143
# Epoch 33/50
# 122/122 - 1s - 11ms/step - loss: 0.0144 - val_loss: 0.0143
# Epoch 34/50
# 122/122 - 2s - 14ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 35/50
# 122/122 - 2s - 14ms/step - loss: 0.0144 - val_loss: 0.0143
# Epoch 36/50
# 122/122 - 2s - 17ms/step - loss: 0.0144 - val_loss: 0.0140
# Epoch 37/50
# 122/122 - 3s - 24ms/step - loss: 0.0143 - val_loss: 0.0139
# Epoch 38/50
# 122/122 - 1s - 11ms/step - loss: 0.0144 - val_loss: 0.0138
# Epoch 39/50
# 122/122 - 1s - 10ms/step - loss: 0.0143 - val_loss: 0.0138
# Epoch 40/50
# 122/122 - 1s - 11ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 41/50
# 122/122 - 1s - 10ms/step - loss: 0.0143 - val_loss: 0.0138
# Epoch 42/50
# 122/122 - 1s - 10ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 43/50
# 122/122 - 1s - 10ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 44/50
# 122/122 - 2s - 14ms/step - loss: 0.0144 - val_loss: 0.0137
# Epoch 45/50
# 122/122 - 1s - 11ms/step - loss: 0.0143 - val_loss: 0.0136
# Epoch 46/50
# 122/122 - 1s - 11ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 47/50
# 122/122 - 2s - 14ms/step - loss: 0.0143 - val_loss: 0.0136
# Epoch 48/50
# 122/122 - 2s - 17ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 49/50
# 122/122 - 1s - 10ms/step - loss: 0.0143 - val_loss: 0.0135
# Epoch 50/50
# 122/122 - 1s - 11ms/step - loss: 0.0142 - val_loss: 0.0134

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
# Calculate MAE
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test MAE: %.3f'%mae)

# Calculate R-squared
r2 = r2_score(inv_y, inv_yhat)
print('R-squared: %.3f'%r2)
# Out:
# Test MAE: 13.437
# R-squared: 0.917
